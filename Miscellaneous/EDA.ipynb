# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../Data/submission_template.csv")

# %%
df
# Out:
#       Latitude  Longitude Sample Date  Total Alkalinity  \
# 0   -32.043333  27.822778  01-09-2014               NaN
# 1   -33.329167  26.077500  16-09-2015               NaN
# 2   -32.991639  27.640028  07-05-2015               NaN
# 3   -34.096389  24.439167  07-02-2012               NaN
# 4   -32.000556  28.581667  01-10-2014               NaN
# ..         ...        ...         ...               ...
# 195 -33.771111  25.386667  06-12-2012               NaN
# 196 -33.185361  27.390750  04-09-2014               NaN
# 197 -32.043333  27.822778  28-09-2015               NaN
# 198 -33.001667  25.161389  08-01-2015               NaN
# 199 -33.237780  26.994720  27-03-2013               NaN
#
#      Electrical Conductance  Dissolved Reactive Phosphorus
# 0                       NaN                            NaN
# 1                       NaN                            NaN
# 2                       NaN                            NaN
# ...

# %%
import datetime

df["Sample Date"] = pd.to_datetime(df["Sample Date"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 import datetime
# ----> 3 df["Sample Date"] = pd.to_datetime(df["Sample Date"])
#
# File ~/Desktop/EY-Data-Challenge/venv/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:1072, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1070         result = arg.map(cache_array)
#    1071     else:
# -> 1072         values = convert_listlike(arg._values, format)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/Desktop/EY-Data-Challenge/venv/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...
